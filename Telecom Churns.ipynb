# %%
ch=pd.read_csv(r"C:\Users\mhaasa\Downloads\archive\churn.csv")
ch.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.hist(ch['tenure'],bins=10,facecolor='grey')
plt.xlabel('tenure')
plt.ylabel('No.of Customers')
plt.show()

# %%
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="Partner",hue="Churn",data=ch)

# %%
import seaborn as sns
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="tenure",hue="Churn",data=ch)

# %% [markdown]
# ### From above Data analysis it can be concluded that less usage of the services results in more churn

# %%
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="PhoneService",hue="Churn",data=ch)

# %%
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="MultipleLines",hue="Churn",data=ch)

# %%
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="InternetService"  , hue="Churn",data=ch)

# %%
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="PaperlessBilling"  , hue="Churn",data=ch)

# %%
sns.set(style="darkgrid",color_codes=True)
sns.countplot(x="Contract"  , hue="Churn",data=ch)

# %% [markdown]
# ### Two year Contract Cutomers are less likely to be churn

# %%
import seaborn as sns
g=sns.FacetGrid(ch,col="Churn")
g.map(plt.hist,"OnlineSecurity")

# %% [markdown]
# ### Due to no Online Security Customers are opting out the service
